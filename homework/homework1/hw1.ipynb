# %%
import random
import os


#Участник выбирает категорию, слова из которой он будет угадывать
def choice():
    a = input('Выберите одну из трех тем: физика, география или философия: ')
    a = a + '.txt'
    while True:
        if os.path.exists(a):
            break
        else:
            a = input('Попробуйте ещё раз. Нужно написать одно из трех слов: физика, география, философия: ')
            a = a + '.txt'
    return a


#Выбираем одно слово из массива слов
def randomizer(f):
    with open(f, 'r', encoding='utf-8') as a:
        text = a.readlines()
    return random.choice(text)


#Служебная функция, которая будет проверять соответствие буквы в слове введенной букве, игнорируя регистр
def equality(a, b):
    try:
        return a.upper() == b.upper()
    except AttributeError:
        return a == b


#Служебная функция: я не придумала, как красиво запринтовать ч/з пробел
def wierdprint(b):
    for i in b:
        print(i, end=' ')
    print('\n')


#Служебная функция, ибо библиотеки европейских алфавитов нет у меня
def alphabet(a):
    i = 'абвгдеёжзийклмнопрстуфхцчшщъыьэюя'
    f = False
    for l, c in enumerate(i):
            f = equality(c, a)
            if f:
                break
    return f


#Служебная функция, проверяющая соответствие введенной буквы критериям
def checker(a, p):
    lett = alphabet(a)
    while lett == False:
        a = input('Кажется, Вы ввели неверный символ. Введите русскую букву: ')
        lett = alphabet(a)
    while a in p:
        print('Вы уже вводили эту букву')
        a = input('Введите другую букву: ')
    return a

#Основной алгоритм, в котором идет игра
def game(w):
    w = w.strip()
    k = 6
    c = 0
    p = []
    print('У вас есть', k, "возможностей ошибиться, отгадывая слово, состоящее из", len(w), 'букв')
    d = ['_' for i in enumerate(w)]
    wierdprint(d)
    while k != 0:
        a = input('Введите букву: ')
        b = False
        a = checker(a,p)
        print(a)
        for i, l in enumerate(w):
            f = equality(a, w[i])
            if f:
                b = True
                d[i] = a
                c += 1
                if c == len(w):
                    k = 0
        if b == False:
            print('Такой буквы в слове нет')
            k = k - 1
            print('Вы можете ошибиться еще', k, 'раз')
        else:
            print('Вы угадали букву!')
            wierdprint(d)
    return c


#Функция, в которой проверяются результаты игры
def player(w):
    p = game(w)
    a = 'N'
    if p == len(w)-1:
        print('Вы угадали слово', w)
    else:
        print('К сожалению, Вы не угадали слово', w)
    a = input('Хотите сыграть ещё раз? Y/N: ')
    return a


#Собираем всё в одну маленькую, чтобы не страдать
def main():
    a = player(randomizer(choice()))
    while a == 'Y':
        player(randomizer(choice()))


main()

# %%
# Out:
# Выберите одну из трех тем: физика, география или философия: физика
# У вас есть 6 возможностей ошибиться, отгадывая слово, состоящее из 9 букв
# _ _ _ _ _ _ _ _ _
#
# Введите букву: о
# Вы угадали букву!
# _ _ _ о _ _ _ _ _
#
# Введите букву: р
# Вы угадали букву!
# _ _ _ о р _ _ _ _
#
# Введите букву: е
# Вы угадали букву!
# _ _ _ о р е _ _ е
#
# Введите букву: н
# Вы угадали букву!
# _ _ _ о р е н _ е
#
# Введите букву: и
# Вы угадали букву!
# _ _ _ о р е н и е
#
# Введите букву: е
# Вы уже вводили эту букву
# Введите другую букву: в
# Вы угадали букву!
# _ _ _ о р е н и е
#
# Введите букву: ц
# Такой буквы в слове нет
# Вы можете ошибиться еще 5 раз
# Введите букву: в
# Такой буквы в слове нет
# Вы можете ошибиться еще 4 раз
# Введите букву: д
# Такой буквы в слове нет
# Вы можете ошибиться еще 3 раз
# Введите букву: у
# Вы угадали букву!
# у _ _ о р е н и е
#
# Вы угадали слово ускорение
#
# Хотите сыграть ещё раз? Y/N: с
